# %% [markdown]
# ### Day 1: Introduction to R and Basic Data Types
# **Morning:**
# 1. Installing R and RStudio
#    - 1.1 Downloading R and RStudio
#    - 1.2 Installing R and RStudio
#    - 1.3 Overview of RStudio interface
#
# 2. Basic R Syntax
#    - 2.1 Comments and basic arithmetic operations
#    - 2.2 Variables and assignment
#
# **Afternoon:**
# 3. Data Types and Structures
#    - 3.1 Vectors
#    - 3.2 Lists
#    - 3.3 Matrices
#    - 3.4 Data frames
#    - 3.5 Factors
#    - 3.6 Basic functions for data types (`length`, `class`, `str`, `summary`)
#
# 4. Practical Exercise:
#    - 4.1 Create vectors, lists, and data frames
#    - 4.2 Perform basic operations on these data structures
#
# ### Day 2: Data Manipulation with dplyr and tidyr
# **Morning:**
# 1. Introduction to Tidyverse
#    - 1.1 Overview of the Tidyverse package
#    - 1.2 Loading Tidyverse packages (`dplyr`, `tidyr`)
#
# 2. Data Manipulation with dplyr
#    - 2.1 Selecting columns (`select`)
#    - 2.2 Filtering rows (`filter`)
#    - 2.3 Arranging rows (`arrange`)
#    - 2.4 Creating new columns (`mutate`)
#    - 2.5 Summarizing data (`summarize`)
#    - 2.6 Grouped operations (`group_by`)
#
# **Afternoon:**
# 3. Data Tidying with tidyr
#    - 3.1 Reshaping data (`gather`, `spread`)
#    - 3.2 Separating and uniting columns (`separate`, `unite`)
#
# 4. Practical Exercise:
#    - 4.1 Use `dplyr` to manipulate a sample dataset
#    - 4.2 Use `tidyr` to tidy a messy dataset
#
# ### Day 3: Data Visualization with ggplot2
# **Morning:**
# 1. Introduction to ggplot2
#    - 1.1 Grammar of graphics
#    - 1.2 Basic structure of a `ggplot2` plot (`ggplot`, `aes`, `geom`)
#
# 2. Creating Basic Plots
#    - 2.1 Scatter plots (`geom_point`)
#    - 2.2 Line plots (`geom_line`)
#    - 2.3 Bar plots (`geom_bar`)
#
# **Afternoon:**
# 3. Advanced ggplot2 Techniques
#    - 3.1 Customizing plots (themes, labels, scales)
#    - 3.2 Faceting for multiple plots (`facet_wrap`, `facet_grid`)
#    - 3.3 Adding statistical transformations (e.g., `geom_smooth`)
#
# 4. Practical Exercise:
#    - 4.1 Create various plots using a sample dataset
#    - 4.2 Customize plots for better presentation
#
# ### Day 4: Statistical Analysis and Reporting
# **Morning:**
# 1. Basic Statistical Analysis in R
#    - 1.1 Descriptive statistics (`mean`, `median`, `sd`, `var`)
#    - 1.2 Correlation and covariance
#    - 1.3 Basic hypothesis testing (t-tests, chi-squared tests)
#
# 2. Linear Regression
#    - 2.1 Simple linear regression (`lm` function)
#    - 2.2 Interpreting regression output
#    - 2.3 Plotting regression lines
#
# **Afternoon:**
# 3. Reporting Results
#    - 3.1 Creating RMarkdown documents
#    - 3.2 Combining code, results, and narrative text
#    - 3.3 Generating HTML, PDF, and Word reports
#
# 4. Practical Exercise:
#    - 4.1 Perform a simple statistical analysis on a sample dataset
#    - 4.2 Create an RMarkdown report documenting the analysis and results

# %%
df <- data.frame(product = c('oven', 'microwave', 'toaster'),
                 price = c(850, 300, 120)
                 )
print(df)
# Out:
#     product price
# 1      oven   850
# 2 microwave   300
# 3   toaster   120
